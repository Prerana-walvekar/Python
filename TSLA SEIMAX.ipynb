# %%
import pandas as pd
import yfinance as yf
from datetime import date ,datetime, timedelta
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from pmdarima import auto_arima
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt

# %%
start_date = '2023-12-1'
end_date = '2024-12-1'
print("Start Date:",start_date," End Date:",end_date)
# Out:
# Start Date: 2023-12-1  End Date: 2024-12-1

# %%
ticker = 'TSLA'

df = yf.download(ticker, start=start_date, end=end_date)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-01  238.830002  238.830002  240.190002  231.899994  233.139999
# 2023-12-04  235.580002  235.580002  239.369995  233.289993  235.750000
# 2023-12-05  238.720001  238.720001  246.660004  233.699997  233.869995
# 2023-12-06  239.369995  239.369995  246.570007  239.169998  242.919998
# 2023-12-07  242.639999  242.639999  244.080002  236.979996  241.550003
# ...                ...         ...         ...         ...         ...
# 2024-11-22  352.559998  352.559998  361.529999  337.700012  341.089996
# 2024-11-25  338.589996  338.589996  361.929993  338.200012  360.140015
# 2024-11-26  338.230011  338.230011  346.959991  335.660004  341.000000
# 2024-11-27  332.890015  332.890015  342.549988  326.589996  341.799988
# 2024-11-29  345.160004  345.160004  345.450012  334.649994  336.079987
#
# Price          Volume
# Ticker           TSLA
# Date
# 2023-12-01  121173500
# 2023-12-04  104099800
# 2023-12-05  137971100
# 2023-12-06  126436200
# 2023-12-07  107142300
# ...               ...
# 2024-11-22   89140700
# 2024-11-25   95890900
# 2024-11-26   62295900
# 2024-11-27   57896400
# 2024-11-29   37167600
#
# [251 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2023-12-01 to 2024-11-29
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, TSLA)  251 non-null    float64
#  1   (Close, TSLA)      251 non-null    float64
#  2   (High, TSLA)       251 non-null    float64
#  3   (Low, TSLA)        251 non-null    float64
#  4   (Open, TSLA)       251 non-null    float64
#  5   (Volume, TSLA)     251 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.7 KB

# %%
df.isnull().sum()
# Out:
# Price      Ticker
# Adj Close  TSLA      0
# Close      TSLA      0
# High       TSLA      0
# Low        TSLA      0
# Open       TSLA      0
# Volume     TSLA      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Open'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close Rolling 10'] = df['Close'].rolling(window=10,min_periods=1).mean()
df.head(14)
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-01  238.830002  238.830002  240.190002  231.899994  233.139999
# 2023-12-04  235.580002  235.580002  239.369995  233.289993  235.750000
# 2023-12-05  238.720001  238.720001  246.660004  233.699997  233.869995
# 2023-12-06  239.369995  239.369995  246.570007  239.169998  242.919998
# 2023-12-07  242.639999  242.639999  244.080002  236.979996  241.550003
# 2023-12-08  243.839996  243.839996  245.270004  239.270004  240.270004
# 2023-12-11  239.740005  239.740005  243.440002  237.449997  242.740005
# 2023-12-12  237.009995  237.009995  238.990005  233.869995  238.550003
# 2023-12-13  239.289993  239.289993  240.300003  228.199997  234.190002
# 2023-12-14  251.050003  251.050003  253.880005  240.789993  241.220001
# 2023-12-15  253.500000  253.500000  254.130005  248.300003  251.210007
# 2023-12-18  252.080002  252.080002  258.739990  251.360001  253.779999
# 2023-12-19  257.220001  257.220001  258.339996  253.009995  253.479996
# 2023-12-20  247.139999  247.139999  259.839996  247.000000  256.410004
#
# Price          Volume Close Rolling 10
# Ticker           TSLA
# Date
# 2023-12-01  121173500       238.830002
# 2023-12-04  104099800       237.205002
# 2023-12-05  137971100       237.710002
# 2023-12-06  126436200       238.125000
# 2023-12-07  107142300       239.028000
# 2023-12-08  102980100       239.829999
# 2023-12-11   97913900       239.817143
# 2023-12-12   95328300       239.466249
# 2023-12-13  146286300       239.446665
# 2023-12-14  160829200       240.606999
# 2023-12-15  135720800       242.073999
# 2023-12-18  116416500       243.723999
# 2023-12-19  106737400       245.573999
# 2023-12-20  125097000       246.350999

# %%
df[['Close','Close Rolling 10']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df['Close Rolling 30'] = df['Close'].rolling(window=30,min_periods=1).mean()

# %%
df['Close Rolling 50'] = df['Close'].rolling(window=50,min_periods=1).mean()
df
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-01  238.830002  238.830002  240.190002  231.899994  233.139999
# 2023-12-04  235.580002  235.580002  239.369995  233.289993  235.750000
# 2023-12-05  238.720001  238.720001  246.660004  233.699997  233.869995
# 2023-12-06  239.369995  239.369995  246.570007  239.169998  242.919998
# 2023-12-07  242.639999  242.639999  244.080002  236.979996  241.550003
# ...                ...         ...         ...         ...         ...
# 2024-11-22  352.559998  352.559998  361.529999  337.700012  341.089996
# 2024-11-25  338.589996  338.589996  361.929993  338.200012  360.140015
# 2024-11-26  338.230011  338.230011  346.959991  335.660004  341.000000
# 2024-11-27  332.890015  332.890015  342.549988  326.589996  341.799988
# 2024-11-29  345.160004  345.160004  345.450012  334.649994  336.079987
#
# Price          Volume Close Rolling 10 Close Rolling 30 Close Rolling 50
# Ticker           TSLA
# Date
# 2023-12-01  121173500       238.830002       238.830002       238.830002
# 2023-12-04  104099800       237.205002       237.205002       237.205002
# 2023-12-05  137971100       237.710002       237.710002       237.710002
# 2023-12-06  126436200       238.125000       238.125000       238.125000
# 2023-12-07  107142300       239.028000       239.028000       239.028000
# ...               ...              ...              ...              ...
# 2024-11-22   89140700       335.959998       277.358000       264.061800
# 2024-11-25   95890900       334.818997       281.338999       266.298000
# 2024-11-26   62295900       335.792999       285.294333       268.505200
# 2024-11-27   57896400       336.058002       289.013000       270.619000
# 2024-11-29   37167600       339.456003       293.155333       272.643800
#
# [251 rows x 9 columns]

# %%
df[['Close','Close Rolling 10','Close Rolling 30','Close Rolling 50']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#cummulative MOving average
df['CMA']=df['Close'].expanding().mean()
df
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-01  238.830002  238.830002  240.190002  231.899994  233.139999
# 2023-12-04  235.580002  235.580002  239.369995  233.289993  235.750000
# 2023-12-05  238.720001  238.720001  246.660004  233.699997  233.869995
# 2023-12-06  239.369995  239.369995  246.570007  239.169998  242.919998
# 2023-12-07  242.639999  242.639999  244.080002  236.979996  241.550003
# ...                ...         ...         ...         ...         ...
# 2024-11-22  352.559998  352.559998  361.529999  337.700012  341.089996
# 2024-11-25  338.589996  338.589996  361.929993  338.200012  360.140015
# 2024-11-26  338.230011  338.230011  346.959991  335.660004  341.000000
# 2024-11-27  332.890015  332.890015  342.549988  326.589996  341.799988
# 2024-11-29  345.160004  345.160004  345.450012  334.649994  336.079987
#
# Price          Volume Close Rolling 10 Close Rolling 30 Close Rolling 50  \
# Ticker           TSLA
# Date
# 2023-12-01  121173500       238.830002       238.830002       238.830002
# 2023-12-04  104099800       237.205002       237.205002       237.205002
# 2023-12-05  137971100       237.710002       237.710002       237.710002
# 2023-12-06  126436200       238.125000       238.125000       238.125000
# 2023-12-07  107142300       239.028000       239.028000       239.028000
# ...               ...              ...              ...              ...
# 2024-11-22   89140700       335.959998       277.358000       264.061800
# 2024-11-25   95890900       334.818997       281.338999       266.298000
# 2024-11-26   62295900       335.792999       285.294333       268.505200
# 2024-11-27   57896400       336.058002       289.013000       270.619000
# 2024-11-29   37167600       339.456003       293.155333       272.643800
#
# Price              CMA
# Ticker
# Date
# 2023-12-01  238.830002
# 2023-12-04  237.205002
# 2023-12-05  237.710002
# 2023-12-06  238.125000
# 2023-12-07  239.028000
# ...                ...
# 2024-11-22  214.444008
# 2024-11-25  214.944597
# 2024-11-26  215.439719
# 2024-11-27  215.909520
# 2024-11-29  216.424462
#
# [251 rows x 10 columns]

# %%
df[['Close','CMA']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def adf_test(series):
    result=adfuller(series)
    print('ADF Statistics: {}'.format(result[0]))
    print('p- value: {}'.format(result[1]))
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adf_test(df['Close'])
# Out:
# ADF Statistics: -0.21546653898451537
# p- value: 0.9366527608531471
# weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary

# %%
df['First Difference'] = df['Close']-df['Close'].shift(1)
df.head()
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-01  238.830002  238.830002  240.190002  231.899994  233.139999
# 2023-12-04  235.580002  235.580002  239.369995  233.289993  235.750000
# 2023-12-05  238.720001  238.720001  246.660004  233.699997  233.869995
# 2023-12-06  239.369995  239.369995  246.570007  239.169998  242.919998
# 2023-12-07  242.639999  242.639999  244.080002  236.979996  241.550003
#
# Price          Volume Close Rolling 10 Close Rolling 30 Close Rolling 50  \
# Ticker           TSLA
# Date
# 2023-12-01  121173500       238.830002       238.830002       238.830002
# 2023-12-04  104099800       237.205002       237.205002       237.205002
# 2023-12-05  137971100       237.710002       237.710002       237.710002
# 2023-12-06  126436200       238.125000       238.125000       238.125000
# 2023-12-07  107142300       239.028000       239.028000       239.028000
#
# Price              CMA First Difference
# Ticker
# Date
# 2023-12-01  238.830002              NaN
# 2023-12-04  237.205002        -3.250000
# 2023-12-05  237.710002         3.139999
# 2023-12-06  238.125000         0.649994
# 2023-12-07  239.028000         3.270004

# %%
adf_test(df['First Difference'].dropna())
# Out:
# ADF Statistics: -15.615983299237971
# p- value: 1.7558357345756553e-28
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
df['12 Difference'] = df['Close']-df['Close'].shift(12)

# %%
adf_test(df['12 Difference'].dropna())
# Out:
# ADF Statistics: -3.197933812741227
# p- value: 0.020104590195697113
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
df['First Difference'].dropna().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
acf = plot_acf(df["First Difference"].dropna())
pacf = plot_pacf(df["First Difference"].dropna())

# %%
step = auto_arima(df['First Difference'].dropna(),trace=True,suppress_warnings=True)
step.summary()
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=inf, Time=7.85 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=1791.632, Time=0.10 sec
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=1793.629, Time=0.33 sec
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=1793.630, Time=0.57 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1790.237, Time=0.16 sec
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=1795.601, Time=2.47 sec
#
# Best model:  ARIMA(0,0,0)(0,0,0)[0]
# Total fit time: 11.525 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  250
# Model:                        SARIMAX   Log Likelihood                -894.118
# Date:                Mon, 16 Dec 2024   AIC                           1790.237
# Time:                        15:37:52   BIC                           1793.758
# Sample:                             0   HQIC                          1791.654
#                                 - 250
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        74.8189      3.503     21.358      0.000      67.953      81.685
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               305.60
# Prob(Q):                              0.96   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.86   Skew:                             0.82
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.16
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_ARIMA=ARIMA(df['Close'],order=(20,1,12))
model_ARIMA_fit = model_ARIMA.fit()
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_ARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                   TSLA   No. Observations:                  251
# Model:               ARIMA(20, 1, 12)   Log Likelihood                -876.373
# Date:                Mon, 16 Dec 2024   AIC                           1818.746
# Time:                        15:38:56   BIC                           1934.954
# Sample:                             0   HQIC                          1865.517
#                                 - 251
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0426      3.073     -0.014      0.989      -6.066       5.981
# ar.L2          0.1277      1.763      0.072      0.942      -3.327       3.582
# ar.L3         -0.1804      0.693     -0.260      0.795      -1.539       1.178
# ar.L4         -0.2515      0.169     -1.486      0.137      -0.583       0.080
# ar.L5         -0.2566      0.726     -0.353      0.724      -1.680       1.167
# ar.L6          0.0302      0.404      0.075      0.940      -0.761       0.822
# ar.L7         -0.0331      0.343     -0.097      0.923      -0.705       0.639
# ar.L8         -0.0592      0.327     -0.181      0.856      -0.700       0.582
# ar.L9         -0.3238      0.116     -2.783      0.005      -0.552      -0.096
# ar.L10         0.2475      0.971      0.255      0.799      -1.655       2.150
# ar.L11        -0.2565      1.357     -0.189      0.850      -2.916       2.403
# ar.L12        -0.3753      1.612     -0.233      0.816      -3.535       2.784
# ar.L13         0.0446      0.173      0.257      0.797      -0.295       0.384
# ar.L14         0.0121      0.230      0.053      0.958      -0.439       0.464
# ar.L15        -0.0466      0.127     -0.366      0.714      -0.296       0.203
# ar.L16         0.0189      0.119      0.159      0.874      -0.214       0.252
# ar.L17         0.0997      0.147      0.678      0.498      -0.189       0.388
# ar.L18         0.0270      0.233      0.116      0.908      -0.430       0.484
# ar.L19        -0.1005      0.111     -0.905      0.365      -0.318       0.117
# ar.L20        -0.0314      0.312     -0.101      0.920      -0.644       0.581
# ma.L1          0.0150      3.297      0.005      0.996      -6.446       6.476
# ma.L2         -0.1067      1.933     -0.055      0.956      -3.895       3.681
# ma.L3          0.2015      0.955      0.211      0.833      -1.671       2.074
# ma.L4          0.2053      0.342      0.601      0.548      -0.465       0.875
# ma.L5          0.1844      0.683      0.270      0.787      -1.154       1.523
# ma.L6          0.0003      0.259      0.001      0.999      -0.508       0.508
# ma.L7          0.0960      0.477      0.201      0.840      -0.839       1.031
# ma.L8          0.1603      0.746      0.215      0.830      -1.301       1.622
# ma.L9          0.4588      0.784      0.585      0.558      -1.077       1.995
# ma.L10        -0.3272      1.253     -0.261      0.794      -2.782       2.128
# ma.L11         0.4881      2.062      0.237      0.813      -3.553       4.529
# ma.L12         0.5253      2.564      0.205      0.838      -4.500       5.550
# sigma2        63.1380     58.790      1.074      0.283     -52.089     178.365
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               404.55
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.84   Skew:                             0.93
# Prob(H) (two-sided):                  0.00   Kurtosis:                         8.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
forecast_steps = 50
forecast = model_ARIMA_fit.forecast(steps=forecast_steps)

# Create a forecasted index (next 30 days)
forecast_index = pd.date_range(start=df.index[-1] + pd.Timedelta(days=0), periods=forecast_steps, freq='B')

# Step 6: Visualize the results
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Observed')

plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.title('ARIMA Model Forecast')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# SARIMA

# %%
acf12 = plot_acf(df["12 Difference"].dropna())
pacf12 = plot_pacf(df["12 Difference"].dropna())

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model_SARIMA=SARIMAX(df['Close'],order=(2,0,8),seasonal_order=(0,1,0,4))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[116], line 2
#       1 from statsmodels.tsa.statespace.sarimax import SARIMAX
# ----> 2 model_SARIMA=SARIMAX(df['Close'],order=(2,0,8),seasonal_order=(0,1,0,0))
#
# File c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:328, in SARIMAX.__init__(self, endog, exog, order, seasonal_order, trend, measurement_error, time_varying_regression, mle_regression, simple_differencing, enforce_stationarity, enforce_invertibility, hamilton_representation, concentrate_scale, trend_offset, use_exact_diffuse, dates, freq, missing, validate_specification, **kwargs)
#     318 def __init__(self, endog, exog=None, order=(1, 0, 0),
#     319              seasonal_order=(0, 0, 0, 0), trend=None,
#     320              measurement_error=False, time_varying_regression=False,
#    (...)
#     325              freq=None, missing='none', validate_specification=True,
#     326              **kwargs):
# --> 328     self._spec = SARIMAXSpecification(
#     329         endog, exog=exog, order=order, seasonal_order=seasonal_order,
#     330         trend=trend, enforce_stationarity=None, enforce_invertibility=None,
#     331         concentrate_scale=concentrate_scale, dates=dates, freq=freq,
#     332         missing=missing, validate_specification=validate_specification)
#     333     self._params = SARIMAXParams(self._spec)
#     335     # Save given orders
#
# File c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\arima\specification.py:307, in SARIMAXSpecification.__init__(self, endog, exog, order, seasonal_order, ar_order, diff, ma_order, seasonal_ar_order, seasonal_diff, seasonal_ma_order, seasonal_periods, trend, enforce_stationarity, enforce_invertibility, concentrate_scale, trend_offset, dates, freq, missing, validate_specification)
#     303         raise ValueError('Seasonal periodicity must be greater'
#     304                          ' than 1.')
#     305     if ((seasonal_order[0] != 0 or seasonal_order[1] != 0 or
#     306             seasonal_order[2] != 0) and seasonal_order[3] == 0):
# --> 307         raise ValueError('Must include nonzero seasonal periodicity if'
#     308                          ' including seasonal AR, MA, or'
#     309                          ' differencing.')
#     311 # Basic order
#     312 self.order = order
#
# ValueError: Must include nonzero seasonal periodicity if including seasonal AR, MA, or differencing.

# %%
model_SARIMA_fit=model_SARIMA.fit()
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
model_SARIMA_fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                               TSLA   No. Observations:                  251
# Model:             SARIMAX(2, 0, 8)x(0, 1, [], 7)   Log Likelihood                -882.357
# Date:                            Mon, 16 Dec 2024   AIC                           1786.714
# Time:                                    16:28:37   BIC                           1825.183
# Sample:                                         0   HQIC                          1802.208
#                                             - 251
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8740      5.036      0.174      0.862      -8.997      10.745
# ar.L2          0.0665      3.605      0.018      0.985      -6.999       7.132
# ma.L1          0.1298      5.050      0.026      0.979      -9.767      10.027
# ma.L2          0.0757      2.295      0.033      0.974      -4.422       4.574
# ma.L3          0.0202      2.334      0.009      0.993      -4.554       4.594
# ma.L4          0.0992      2.157      0.046      0.963      -4.128       4.327
# ma.L5          0.0491      2.409      0.020      0.984      -4.672       4.770
# ma.L6          0.0543      2.298      0.024      0.981      -4.449       4.558
# ma.L7         -0.9149      2.327     -0.393      0.694      -5.475       3.645
# ma.L8         -0.0818      3.483     -0.023      0.981      -6.907       6.744
# sigma2        74.8642      8.967      8.349      0.000      57.289      92.439
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               254.97
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.18   Skew:                             0.87
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.70
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
train_dataset_end=datetime(2024,11,1)
test_dataset_end=datetime(2024,12,1)
train_data=df[:train_dataset_end]
test_data=df[train_dataset_end+timedelta(days=1):test_dataset_end]
pred_start_date=test_data.index[0]
pred_end_date=test_data.index[-1]

# %%
train_data
# Out:
# Price        Adj Close       Close        High         Low        Open  \
# Ticker            TSLA        TSLA        TSLA        TSLA        TSLA
# Date
# 2023-12-01  238.830002  238.830002  240.190002  231.899994  233.139999
# 2023-12-04  235.580002  235.580002  239.369995  233.289993  235.750000
# 2023-12-05  238.720001  238.720001  246.660004  233.699997  233.869995
# 2023-12-06  239.369995  239.369995  246.570007  239.169998  242.919998
# 2023-12-07  242.639999  242.639999  244.080002  236.979996  241.550003
# ...                ...         ...         ...         ...         ...
# 2024-10-28  262.510010  262.510010  273.540009  262.239990  270.000000
# 2024-10-29  259.519989  259.519989  264.980011  255.509995  264.510010
# 2024-10-30  257.549988  257.549988  263.350006  255.820007  258.040009
# 2024-10-31  249.850006  249.850006  259.750000  249.250000  257.989990
# 2024-11-01  248.979996  248.979996  254.000000  246.630005  252.039993
#
# Price          Volume Close Rolling 10 Close Rolling 30 Close Rolling 50  \
# Ticker           TSLA
# Date
# 2023-12-01  121173500       238.830002       238.830002       238.830002
# 2023-12-04  104099800       237.205002       237.205002       237.205002
# 2023-12-05  137971100       237.710002       237.710002       237.710002
# 2023-12-06  126436200       238.125000       238.125000       238.125000
# 2023-12-07  107142300       239.028000       239.028000       239.028000
# ...               ...              ...              ...              ...
# 2024-10-28  107653600       232.514003       239.995668       231.497201
# 2024-10-29   80521800       236.509001       241.050667       232.233201
# 2024-10-30   53993600       240.131000       242.062334       232.962201
# 2024-10-31   66575300       243.027000       242.260001       233.493801
# 2024-11-01   57544800       245.855000       242.617667       234.260201
#
# Price              CMA First Difference 12 Difference Predicted_SARIMA
# Ticker
# Date
# 2023-12-01  238.830002              NaN           NaN         0.000000
# 2023-12-04  237.205002        -3.250000           NaN         0.216976
# 2023-12-05  237.710002         3.139999           NaN         0.412562
# 2023-12-06  238.125000         0.649994           NaN         0.593604
# 2023-12-07  239.028000         3.270004           NaN         0.759881
# ...                ...              ...           ...              ...
# 2024-10-28  206.979079        -6.679993     23.740005       263.223370
# 2024-10-29  207.208515        -2.990021     41.719986       255.645583
# 2024-10-30  207.427391        -1.970001     38.389984       273.578800
# 2024-10-31  207.611039        -7.699982     30.279999       257.757009
# 2024-11-01  207.789354        -0.870010     27.649994       244.389016
#
# [232 rows x 13 columns]

# %%
pred_Sarima=model_SARIMA_fit.predict(start=datetime(2023,12,1),end=datetime(2024,11,1))
residuals=train_data['Close']-pred_Sarima

# %%
model_SARIMA_fit.resid.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
model_SARIMA_fit.resid.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
train_data['Predicted_SARIMA']=pred_Sarima
# Out:
# C:\Users\Prerana Walvekar\AppData\Local\Temp\ipykernel_20304\2338809011.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Predicted_SARIMA']=pred_Sarima

# %%
train_data[['Close','Predicted_SARIMA']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
forecast_steps = 50
forecast = model_SARIMA_fit.forecast(steps=forecast_steps)

# Create a forecasted index (next 30 days)
forecast_index = pd.date_range(start=df.index[-1] + pd.Timedelta(days=0), periods=forecast_steps, freq='B')

# Step 6: Visualize the results
plt.figure(figsize=(10, 5))
plt.plot(df['Close'], label='Observed')

plt.plot(forecast_index, forecast, label='Forecast', color='red')
plt.title('SARIMA Model Forecast')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.legend()
plt.show()
# Out:
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\Prerana Walvekar\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
